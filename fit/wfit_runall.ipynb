# %%
import ROOT
from ROOT import TH1D, TF1
    
def runfit(filename):

    ## Open the file

    datadir = "./data/"
    path = datadir + filename

    outputdir = "./output/"

    file = ROOT.TFile.Open(path)

    ## Get histograms
    Continuum_Bkg = file.Get("Continuum_Bkg")
    GGHH = file.Get("GGHH")
    GGH  = file.Get("GGH")
    VBFH = file.Get("VBFH")
    VH   = file.Get("VH")
    ttH  = file.Get("ttH")
    tHq  = file.Get("tHq")

    # define single H bkg histo
    hSH = TH1D("hSH", "Single H Bkg.", 80, 100, 180)
    hSH.Add(GGH)
    hSH.Add(VBFH)
    hSH.Add(VH)
    hSH.Add(ttH)
    hSH.Add(tHq)

    # define full bkg histo
    hFB = TH1D("hFB", "Full Bkg.", 80, 100, 180)
    hFB.Add(hSH, Continuum_Bkg)

    # define signal + full bkg histo
    hSB = TH1D("hSB", "Signal + Bkg.", 80, 100, 180)
    hSB.Add(hFB, GGHH)

    # create histo that contains only the Higgs peak and fit it
    hpeak = TH1D("hpeak", "Single H + signal", 80, 100, 180)
    hpeak.Add(hSH, GGHH)

    peak_fit = ROOT.TF1("peak_fit", "gaus", 100, 180, 3)
    hpeak.Fit(peak_fit, "0 S WL")

    # Fit signal + background model using the parameters of the peak fit
    fit = ROOT.TF1("fit", "exp([0]+[1]*x)+[2]*exp(-0.5*((x-[3])/[4])^2)", 100, 180)
    fit.FixParameter(2, peak_fit.GetParameter(0))
    fit.FixParameter(3, peak_fit.GetParameter(1))
    fit.FixParameter(4, peak_fit.GetParameter(2))
    fit.SetLineColor(8)
    fit.SetLineStyle(1)
    fit.SetLineWidth(2)
    hSB.Fit("fit", "0 S WL", "", 100, 180)

    # fit the singleH only (to be subtracted from the pseudo-data in the ratio plot)
    singleH_fit = ROOT.TF1("singleH_fit", "gaus", 100, 180, 3)
    hSH.Fit(singleH_fit, "0 S WL")

    ## Create canvas with two pads for the main plot and the pseudodata - bkg
    c = ROOT.TCanvas("c", "", 700, 650)
    upper_pad = ROOT.TPad("upper_pad", "", 0, 0.35, 1, 1)
    lower_pad = ROOT.TPad("lower_pad", "", 0, 0, 1, 0.35)
    for p in [upper_pad, lower_pad]:
        p.SetLeftMargin(0.14)
        p.SetRightMargin(0.05)
        p.SetTickx(False)
        p.SetTicky(False)
    upper_pad.SetBottomMargin(0)
    lower_pad.SetTopMargin(0)
    lower_pad.SetBottomMargin(0.3)

    upper_pad.Draw()
    lower_pad.Draw()

    # select upper pad (main plot)
    upper_pad.cd()

    # create pseudodata histo and fill with "fit"
    hPD = TH1D("hPD", "Pseudo data", 20, 100, 180)

    for i in range(int(hSB.Integral()/4)):
        hPD.Fill(fit.GetRandom());

    # draw pseudodata
    for h in [hPD]:
        h.SetMarkerStyle(20)
        h.SetMarkerSize(1.2)
        h.SetLineWidth(2)
        h.SetLineColor(ROOT.kBlack)
        h.GetYaxis().SetLabelSize(0.045)
        h.GetYaxis().SetTitleSize(0.05)
        h.GetYaxis().SetTitle("Events")
        h.SetStats(0)
        h.SetTitle("")
        h.Draw("E")

    # Draw fit
    fit.Draw("SAME")

    # create cont bkg fit function with the expo parameters of the "fit" and draw
    cont_bkg_fit = ROOT.TF1("cont_bkg", "exp([0]+[1]*x)", 100, 180)
    for i in range(2):
        cont_bkg_fit.SetParameter(i, fit.GetParameter(i))
    cont_bkg_fit.SetLineColor(4)
    cont_bkg_fit.SetLineStyle(2)
    cont_bkg_fit.SetLineWidth(2)
    cont_bkg_fit.Draw("SAME")

    # Draw ratio
    lower_pad.cd()
    
    # create signal histo for ratio plot, evaluate with "fit" parameters, subtract cont. bkg and single H bkg
    ratiosig = ROOT.TH1F("ratiosig", "ratiosig", 5000, 100, 180)
    ratiosig.Eval(fit) # equivalent to ratiosig.Add(fit, 1)
    ratiosig.SetLineColor(2)
    ratiosig.SetLineStyle(1)
    ratiosig.SetLineWidth(2)
    ratiosig.Add(cont_bkg_fit, -1)
    ratiosig.Add(singleH_fit, -1)
    ratiosig.Scale(1000)

    # define pad properties
    ratiopad = ROOT.TH1I("zero", "", 80, 100, 180)
    ratiopad.SetStats(0)
    ratiopad.SetLineColor(4)
    ratiopad.SetLineStyle(2)
    ratiopad.SetLineWidth(2)
    ratiopad.SetMinimum(int(ratiosig.GetMaximum())*(-1))
    ratiopad.SetMaximum(int(ratiosig.GetMaximum())*1.5)
    ratiopad.GetXaxis().SetLabelSize(0.08)
    ratiopad.GetXaxis().SetTitleSize(0.09)
    #ratiopad.GetXaxis().SetTitleOffset(1.0)
    ratiopad.GetYaxis().SetLabelSize(0.08)
    ratiopad.GetYaxis().SetTitleSize(0.08)
    ratiopad.GetYaxis().SetTitle("Pseudo-data - Bkg.")
    ratiopad.GetYaxis().CenterTitle()
    ratiopad.GetYaxis().SetTitleOffset(0.7)
    #ratiopad.GetYaxis().SetNdivisions(503, False)
    ratiopad.GetYaxis().ChangeLabel(-1, -1, 0)
    ratiopad.GetXaxis().SetTitle("Di-photon Invariant mass [GeV]")
    ratiopad.Draw("AXIS")
    
    # draw ratiosig
    ratiosig.Draw("SAME")
    
    # create pseudo-data histo and subtract cont. bkg and single H bkg
    ratiodata = hPD.Clone()
    ratiodata.Add(cont_bkg_fit, -1)
    ratiodata.Add(singleH_fit, -1)
    for i in range(1, hPD.GetNbinsX()):
        ratiodata.SetBinError(i, hPD.GetBinError(i))
    ratiodata.Draw("E SAME")
    
    # Add legend
    upper_pad.cd()
    legend = ROOT.TLegend(0.6, 0.6, 0.94, 0.85)
    legend.SetTextFont(42)
    legend.SetFillStyle(0)
    legend.SetBorderSize(0)
    legend.SetTextSize(0.05)
    legend.SetTextAlign(32)
    legend.AddEntry(hPD, "Pseudo-data" ,"lep")
    legend.AddEntry(cont_bkg_fit, "Continuum Bkg.", "l")
    legend.AddEntry(fit, "Signal + Full Bkg.", "l")
    legend.AddEntry(ratiosig, "Signal x 1000", "l")
    legend.Draw()

    # Add CMS label
    text = ROOT.TLatex()
    text.SetNDC()

    text.SetTextFont(72)
    text.SetTextSize(0.05)
    text.DrawLatex(0.15, 0.91, "CMS")

    text.SetTextFont(42)
    text.SetTextSize(0.045)
    text.DrawLatex(0.24, 0.91, "Phase 2 Simulation Preliminary")

    text.SetTextSize(0.04)
    text.DrawLatex(0.7, 0.91, "#sqrt{s} = 14 TeV, 3000fb^{-1}")

    get_ipython().run_line_magic('jsroot', 'on')
    #c.Draw()
    
    c.SaveAs(outputdir + filename.rstrip(".root")+"_FIT.pdf")
    
    print("Loop finished")

# %%
filelist = [
    "Inv_mass_gghasOneL_DNN_HL.root",
    "Inv_mass_gghasOneL_DNN_2_HL.root",
    "Inv_mass_gghasOneL_DNN_3_HL.root",
    "Inv_mass_gghasOneL_DNN_4_HL.root",
    "Inv_mass_gghasOneL_HL.root",
    "Inv_mass_gghasTwoL_HL.root",
    "Inv_mass_gghasZeroL_bbggOnly_HL.root",
    "Inv_mass_gghasZeroL_DNN_HL.root",
    "Inv_mass_gghasZeroL_DNN_2_HL.root",
    "Inv_mass_gghasZeroL_DNN_3_HL.root",
    "Inv_mass_gghasZeroL_DNN_4_HL.root",
    "Inv_mass_gghasZeroL_HL.root",
    "Mgg_c3_DNN_2_HL.root",
    "Mgg_c3_DNN_HL.root",
    "Mgg_c3_HL.root",
    "Mgg_c4_Zveto_HL.root"
]

# %%
for file in filelist:
    runfit(file)
# Out:
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
# Loop finished
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =       262.21
# Chi2                      =      6736.06
# NDf                       =           77
# Edm                       =  4.39515e-09
# NCalls                    =           91
# Constant                  =      88.4662   +/-   3.53639
# Mean                      =      125.119   +/-   0.119406
# Sigma                     =      3.80596   +/-   0.0532188    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      6496.24
# Chi2                      =      186.593
# NDf                       =           78
# Edm                       =  9.99337e-08
# NCalls                    =           84
# p0                        =       11.474   +/-   0.125917
# p1                        =   -0.0253811   +/-   0.000959294
# p2                        =      88.4662                      	 (fixed)
# p3                        =      125.119                      	 (fixed)
# p4                        =      3.80596                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      260.998
# Chi2                      =      6673.75
# NDf                       =           77
# Edm                       =  4.35131e-09
# NCalls                    =           70
# Constant                  =      88.2042   +/-   3.5382
# Mean                      =      125.118   +/-   0.119763
# Sigma                     =      3.80427   +/-   0.0534163    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      39.4113
# Chi2                      =      1705.17
# NDf                       =           77
# Edm                       =   1.1452e-06
# NCalls                    =           83
# Constant                  =      16.4302   +/-   1.26077
# Mean                      =      124.803   +/-   0.162925
# Sigma                     =      3.63851   +/-   0.0909984    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      5610.02
# Chi2                      =  1.23377e+10
# NDf                       =           78
# Edm                       =  2.09542e-09
# NCalls                    =           83
# p0                        =      10.0463   +/-   0.260042
# p1                        =   -0.0357767   +/-   0.00175537
# p2                        =      16.4302                      	 (fixed)
# p3                        =      124.803                      	 (fixed)
# p4                        =      3.63851                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      39.0824
# Chi2                      =      1651.07
# NDf                       =           77
# Edm                       =  1.14747e-06
# NCalls                    =           60
# Constant                  =      16.1926   +/-   1.25972
# Mean                      =      124.799   +/-   0.165215
# Sigma                     =      3.64315   +/-   0.0922882    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      14.2635
# Chi2                      =      724.403
# NDf                       =           77
# Edm                       =  6.38817e-08
# NCalls                    =           83
# Constant                  =      9.25704   +/-   1.26257
# Mean                      =      125.055   +/-   0.387003
# Sigma                     =      3.47525   +/-   0.273622     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      4883.28
# Chi2                      =  3.25983e+10
# NDf                       =           78
# Edm                       =  1.21415e-07
# NCalls                    =           78
# p0                        =      9.02357   +/-   0.0772285
# p1                        =    -0.034373   +/-   0.000617009
# p2                        =      9.25704                      	 (fixed)
# p3                        =      125.055                      	 (fixed)
# p4                        =      3.47525                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      14.0742
# Chi2                      =      736.713
# NDf                       =           77
# Edm                       =  6.96669e-08
# NCalls                    =           62
# Constant                  =       8.9472   +/-   1.23882
# Mean                      =      125.056   +/-   0.394422
# Sigma                     =      3.48894   +/-   0.278866     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      17.5798
# Chi2                      =  1.16297e+06
# NDf                       =           77
# Edm                       =  3.88411e-09
# NCalls                    =           85
# Constant                  =      2.19115   +/-   0.386924
# Mean                      =      123.709   +/-   0.399357
# Sigma                     =      5.55958   +/-   0.767328     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      1103.59
# Chi2                      =  1.65455e+11
# NDf                       =           78
# Edm                       =   6.7751e-10
# NCalls                    =           81
# p0                        =      7.94666   +/-   0.455664
# p1                        =   -0.0405249   +/-   0.00315648
# p2                        =      2.19115                      	 (fixed)
# p3                        =      123.709                      	 (fixed)
# p4                        =      5.55958                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      17.0928
# Chi2                      =  1.01529e+07
# NDf                       =           77
# Edm                       =  1.10467e-08
# NCalls                    =           73
# Constant                  =       2.0303   +/-   0.375898
# Mean                      =      123.634   +/-   0.430473
# Sigma                     =      5.66794   +/-   0.812759     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =       717.81
# Chi2                      =      8830.36
# NDf                       =           77
# Edm                       =  1.93215e-08
# NCalls                    =           91
# Constant                  =      201.634   +/-   5.71427
# Mean                      =      125.177   +/-   0.0893026
# Sigma                     =      4.03611   +/-   0.0457583    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      7883.64
# Chi2                      =      106.949
# NDf                       =           78
# Edm                       =  1.19652e-06
# NCalls                    =           79
# p0                        =      11.8157   +/-   0.0744213
# p1                        =   -0.0177156   +/-   0.000560832
# p2                        =      201.634                      	 (fixed)
# p3                        =      125.177                      	 (fixed)
# p4                        =      4.03611                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      715.137
# Chi2                      =      8784.05
# NDf                       =           77
# Edm                       =   1.9658e-08
# NCalls                    =           70
# Constant                  =      200.635   +/-   5.71218
# Mean                      =      125.177   +/-   0.089733
# Sigma                     =      4.03753   +/-   0.0459498    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      2.75164
# Chi2                      =  1.89557e+06
# NDf                       =           77
# Edm                       =  9.22453e-07
# NCalls                    =           85
# Constant                  =     0.544222   +/-   0.0314468
# Mean                      =      125.273   +/-   0.193577
# Sigma                     =      4.37072   +/-   0.0616955    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      658.446
# Chi2                      =  1.97602e+12
# NDf                       =           78
# Edm                       =  1.57763e-09
# NCalls                    =           57
# p0                        =      2.66248   +/-   0.323198
# p1                        = -2.03017e-05   +/-   0.0027644
# p2                        =     0.544222                      	 (fixed)
# p3                        =      125.273                      	 (fixed)
# p4                        =      4.37072                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      2.67958
# Chi2                      =  2.96054e+07
# NDf                       =           77
# Edm                       =  1.22403e-06
# NCalls                    =           63
# Constant                  =     0.504395   +/-   0.0304839
# Mean                      =      125.282   +/-   0.210316
# Sigma                     =      4.43151   +/-   0.0555635    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      476.632
# Chi2                      =      2087.18
# NDf                       =           77
# Edm                       =  1.55851e-08
# NCalls                    =           91
# Constant                  =      163.853   +/-   6.60299
# Mean                      =      125.334   +/-   0.148481
# Sigma                     =      3.83126   +/-   0.0604353    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      3037.76
# Chi2                      =      120.741
# NDf                       =           78
# Edm                       =   3.1051e-07
# NCalls                    =           91
# p0                        =      10.2455   +/-   0.0638518
# p1                        =    -0.010974   +/-   0.000471021
# p2                        =      163.853                      	 (fixed)
# p3                        =      125.334                      	 (fixed)
# p4                        =      3.83126                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      475.207
# Chi2                      =      2080.66
# NDf                       =           77
# Edm                       =  1.58575e-08
# NCalls                    =           70
# Constant                  =      163.164   +/-   6.59629
# Mean                      =      125.335   +/-   0.149132
# Sigma                     =      3.83224   +/-   0.0605321    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      89.4863
# Chi2                      =       1794.3
# NDf                       =           77
# Edm                       =  3.26295e-08
# NCalls                    =           94
# Constant                  =      53.0591   +/-   4.15943
# Mean                      =      124.884   +/-   0.248199
# Sigma                     =      3.39541   +/-   0.114266     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      2322.32
# Chi2                      =      535.702
# NDf                       =           78
# Edm                       =  5.27147e-08
# NCalls                    =           78
# p0                        =      8.71986   +/-   0.121761
# p1                        =   -0.0224837   +/-   0.000819594
# p2                        =      53.0591                      	 (fixed)
# p3                        =      124.884                      	 (fixed)
# p4                        =      3.39541                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      89.4166
# Chi2                      =      1791.13
# NDf                       =           77
# Edm                       =  3.13166e-08
# NCalls                    =           71
# Constant                  =      52.7475   +/-   4.15338
# Mean                      =      124.884   +/-   0.249621
# Sigma                     =      3.39715   +/-   0.114584     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      15.3805
# Chi2                      =       578256
# NDf                       =           77
# Edm                       =  1.26431e-07
# NCalls                    =           82
# Constant                  =      7.39852   +/-   1.71771
# Mean                      =      125.035   +/-   0.39708
# Sigma                     =      3.33561   +/-   0.359672     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      535.201
# Chi2                      =  1.62755e+11
# NDf                       =           78
# Edm                       =  4.61233e-08
# NCalls                    =           71
# p0                        =      8.41056   +/-   0.692487
# p1                        =   -0.0464073   +/-   0.00493758
# p2                        =      7.39852                      	 (fixed)
# p3                        =      125.035                      	 (fixed)
# p4                        =      3.33561                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      15.4636
# Chi2                      =  8.72648e+06
# NDf                       =           77
# Edm                       =  1.28062e-07
# NCalls                    =           59
# Constant                  =      7.35832   +/-   1.71727
# Mean                      =      125.036   +/-   0.398
# Sigma                     =      3.33663   +/-   0.361574     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      16.1497
# Chi2                      =       454683
# NDf                       =           77
# Edm                       =  8.34731e-10
# NCalls                    =           92
# Constant                  =      4.70528   +/-   1.30008
# Mean                      =      125.006   +/-   0.525493
# Sigma                     =      3.39114   +/-   0.453943     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      480.462
# Chi2                      =  7.23143e+11
# NDf                       =           78
# Edm                       =  5.88041e-09
# NCalls                    =           78
# p0                        =      3.59074   +/-   0.242454
# p1                        =   -0.0138001   +/-   0.00161394
# p2                        =      4.70528                      	 (fixed)
# p3                        =      125.006                      	 (fixed)
# p4                        =      3.39114                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      16.2551
# Chi2                      =  2.87255e+07
# NDf                       =           77
# Edm                       =  2.69772e-09
# NCalls                    =           70
# Constant                  =      4.67746   +/-   1.29993
# Mean                      =      125.005   +/-   0.527362
# Sigma                     =      3.39221   +/-   0.45663      	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      24.2612
# Chi2                      =      1258.55
# NDf                       =           77
# Edm                       =  1.81184e-07
# NCalls                    =           89
# Constant                  =      11.0559   +/-   1.91032
# Mean                      =      125.262   +/-   0.404438
# Sigma                     =      3.37328   +/-   0.234755     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =       1833.5
# Chi2                      =      6759.41
# NDf                       =           78
# Edm                       =  2.08148e-07
# NCalls                    =           68
# p0                        =      7.39935   +/-   0.249114
# p1                        =   -0.0246639   +/-   0.0015767
# p2                        =      11.0559                      	 (fixed)
# p3                        =      125.262                      	 (fixed)
# p4                        =      3.37328                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      24.3092
# Chi2                      =      1243.65
# NDf                       =           77
# Edm                       =  4.02349e-09
# NCalls                    =           71
# Constant                  =      10.9281   +/-   1.90845
# Mean                      =      125.265   +/-   0.408387
# Sigma                     =      3.37535   +/-   0.23675      	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      951.195
# Chi2                      =      7257.05
# NDf                       =           77
# Edm                       =  5.85422e-08
# NCalls                    =           88
# Constant                  =      305.258   +/-   7.51329
# Mean                      =      125.241   +/-   0.0881362
# Sigma                     =       3.9222   +/-   0.0338471    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      2287.57
# Chi2                      =      80.8217
# NDf                       =           78
# Edm                       =  1.16161e-09
# NCalls                    =           82
# p0                        =      10.7212   +/-   0.0532215
# p1                        =   -0.0114906   +/-   0.000391771
# p2                        =      305.258                      	 (fixed)
# p3                        =      125.241                      	 (fixed)
# p4                        =       3.9222                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      945.787
# Chi2                      =       7252.9
# NDf                       =           77
# Edm                       =   6.2243e-08
# NCalls                    =           69
# Constant                  =       302.02   +/-   7.49907
# Mean                      =      125.243   +/-   0.0890501
# Sigma                     =      3.92722   +/-   0.0339865    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      10.6671
# Chi2                      =       608.97
# NDf                       =           77
# Edm                       =  3.13288e-07
# NCalls                    =           82
# Constant                  =      8.93525   +/-   1.08783
# Mean                      =      124.925   +/-   0.272284
# Sigma                     =      3.04994   +/-   0.15426      	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      4124.49
# Chi2                      =  4.17823e+12
# NDf                       =           78
# Edm                       =  7.43746e-07
# NCalls                    =           68
# p0                        =      7.16372   +/-   0.221351
# p1                        =   -0.0216822   +/-   0.0014743
# p2                        =      8.93525                      	 (fixed)
# p3                        =      124.925                      	 (fixed)
# p4                        =      3.04994                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =       10.671
# Chi2                      =      555.235
# NDf                       =           77
# Edm                       =  3.26062e-07
# NCalls                    =           59
# Constant                  =      8.74863   +/-   1.09003
# Mean                      =      124.924   +/-   0.278113
# Sigma                     =      3.04982   +/-   0.158296     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      79.1138
# Chi2                      =      2025.71
# NDf                       =           77
# Edm                       =  1.81988e-10
# NCalls                    =           92
# Constant                  =      39.2388   +/-   3.82989
# Mean                      =      125.231   +/-   0.21837
# Sigma                     =      3.22652   +/-   0.106435     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      4182.53
# Chi2                      =      441.621
# NDf                       =           78
# Edm                       =  1.21511e-08
# NCalls                    =           79
# p0                        =      10.0458   +/-   0.154002
# p1                        =    -0.022809   +/-   0.00118554
# p2                        =      39.2388                      	 (fixed)
# p3                        =      125.231                      	 (fixed)
# p4                        =      3.22652                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      78.5216
# Chi2                      =      1970.64
# NDf                       =           77
# Edm                       =  1.77742e-10
# NCalls                    =           69
# Constant                  =      39.1208   +/-   3.83548
# Mean                      =      125.231   +/-   0.219101
# Sigma                     =      3.22159   +/-   0.107004     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      303.739
# Chi2                      =      3537.96
# NDf                       =           77
# Edm                       =  9.69658e-11
# NCalls                    =           87
# Constant                  =      122.292   +/-   6.08503
# Mean                      =      125.175   +/-   0.140048
# Sigma                     =      3.37596   +/-   0.0561412    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      5334.27
# Chi2                      =      91.5955
# NDf                       =           78
# Edm                       =   5.6372e-09
# NCalls                    =           82
# p0                        =      11.2702   +/-   0.0947514
# p1                        =   -0.0188802   +/-   0.000716437
# p2                        =      122.292                      	 (fixed)
# p3                        =      125.175                      	 (fixed)
# p4                        =      3.37596                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      302.598
# Chi2                      =      3500.33
# NDf                       =           77
# Edm                       =  9.63762e-11
# NCalls                    =           70
# Constant                  =      121.999   +/-   6.08538
# Mean                      =      125.174   +/-   0.140482
# Sigma                     =      3.37366   +/-   0.0562999    	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      5.84513
# Chi2                      =       301066
# NDf                       =           77
# Edm                       =  7.37614e-09
# NCalls                    =           92
# Constant                  =      1.26122   +/-   0.197946
# Mean                      =      125.079   +/-   0.367595
# Sigma                     =      4.29206   +/-   0.241237     	 (limited)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      1567.94
# Chi2                      =  9.43828e+12
# NDf                       =           78
# Edm                       =  2.50823e-08
# NCalls                    =           69
# p0                        =      5.15028   +/-   0.392805
# p1                        =   -0.0120092   +/-   0.00309658
# p2                        =      1.26122                      	 (fixed)
# p3                        =      125.079                      	 (fixed)
# p4                        =      4.29206                      	 (fixed)
#
# ****************************************
# Minimizer is Minuit / Migrad
# MinFCN                    =      5.80298
# Chi2                      =   1.4153e+06
# NDf                       =           77
# Edm                       =   1.4385e-08
# NCalls                    =           69
# Constant                  =      1.23681   +/-   0.197369
# Mean                      =      125.078   +/-   0.375674
# Sigma                     =      4.30522   +/-   0.246049     	 (limited)
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasOneL_DNN_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasOneL_DNN_2_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Error in <TMinuitMinimizer::GetHessianMatrix>: Hessian matrix has not been computed - status 1
# Error in <ROOT::Math::Fitter::ApplyWeightCorrection>: Error retrieving Hesse on weight2 likelihood - cannot compute errors
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Error in <TMinuitMinimizer::GetHessianMatrix>: Hessian matrix has not been computed - status 1
# Error in <ROOT::Math::Fitter::ApplyWeightCorrection>: Error retrieving Hesse on weight2 likelihood - cannot compute errors
# Warning in <Fit>: Abnormal termination of minimization.
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Error in <TMinuitMinimizer::GetHessianMatrix>: Hessian matrix has not been computed - status 1
# Error in <ROOT::Math::Fitter::ApplyWeightCorrection>: Error retrieving Hesse on weight2 likelihood - cannot compute errors
# Warning in <Fit>: Abnormal termination of minimization.
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasOneL_DNN_3_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasOneL_DNN_4_HL_FIT.pdf has been created
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasOneL_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasTwoL_HL_FIT.pdf has been created
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_bbggOnly_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_DNN_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_DNN_2_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_DNN_3_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_DNN_4_HL_FIT.pdf has been created
# Info in <TCanvas::Print>: pdf file ./output/Inv_mass_gghasZeroL_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Mgg_c3_DNN_2_HL_FIT.pdf has been created
# Info in <TCanvas::Print>: pdf file ./output/Mgg_c3_DNN_HL_FIT.pdf has been created
# Info in <TCanvas::Print>: pdf file ./output/Mgg_c3_HL_FIT.pdf has been created
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood is not accurate, the errors may be not reliable
# Warning in <ROOT::Math::Fitter::ApplyWeightCorrection>: Covariance matrix for weighted likelihood was forced to be defined positive
# Info in <TCanvas::Print>: pdf file ./output/Mgg_c4_Zveto_HL_FIT.pdf has been created
